# %%
import numpy as np

# %%
import pandas as pd

# %%
import tushare as ts

# %%
df = pd.read_csv('./data/000001.csv')

# %%
df
# Out:
#       Unnamed: 0    ts_code  trade_date   open   high    low  close  \
# 0              0  000001.SZ    20190402  13.28  13.48  13.23  13.36
# 1              1  000001.SZ    20190401  12.83  13.55  12.83  13.18
# 2              2  000001.SZ    20190329  12.26  12.82  12.21  12.82
# 3              3  000001.SZ    20190328  12.31  12.31  12.10  12.22
# 4              4  000001.SZ    20190327  12.24  12.47  12.18  12.38
# 5              5  000001.SZ    20190326  12.23  12.29  12.01  12.10
# 6              6  000001.SZ    20190325  12.40  12.40  12.10  12.11
# 7              7  000001.SZ    20190322  12.69  12.74  12.50  12.59
# 8              8  000001.SZ    20190321  12.77  12.80  12.58  12.69
# 9              9  000001.SZ    20190320  12.68  12.88  12.62  12.75
# 10            10  000001.SZ    20190319  12.92  12.94  12.61  12.79
# 11            11  000001.SZ    20190318  12.53  12.94  12.32  12.91
# 12            12  000001.SZ    20190315  12.34  12.68  12.34  12.50
# ...

# %%
df.plot()

# %%
ma_list = [5, 10, 20, 100]

# %%
for ma in ma_list:
    df['MA_' + str(ma)] = df['close'].rolling(ma).mean()
for ema in ma_list:
    df['EMA' + str(ema)] = df['close'].ewm(span = 5).mean()

# %%
df.fillna(value = 0)
# Out:
#       Unnamed: 0    ts_code  trade_date   open   high    low  close  \
# 0              0  000001.SZ    20190402  13.28  13.48  13.23  13.36
# 1              1  000001.SZ    20190401  12.83  13.55  12.83  13.18
# 2              2  000001.SZ    20190329  12.26  12.82  12.21  12.82
# 3              3  000001.SZ    20190328  12.31  12.31  12.10  12.22
# 4              4  000001.SZ    20190327  12.24  12.47  12.18  12.38
# 5              5  000001.SZ    20190326  12.23  12.29  12.01  12.10
# 6              6  000001.SZ    20190325  12.40  12.40  12.10  12.11
# 7              7  000001.SZ    20190322  12.69  12.74  12.50  12.59
# 8              8  000001.SZ    20190321  12.77  12.80  12.58  12.69
# 9              9  000001.SZ    20190320  12.68  12.88  12.62  12.75
# 10            10  000001.SZ    20190319  12.92  12.94  12.61  12.79
# 11            11  000001.SZ    20190318  12.53  12.94  12.32  12.91
# 12            12  000001.SZ    20190315  12.34  12.68  12.34  12.50
# ...

# %%
df['close'].rolling(5).mean()
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4       12.792
# 5       12.540
# 6       12.326
# 7       12.280
# 8       12.374
# 9       12.448
# 10      12.586
# 11      12.746
# 12      12.728
# 13      12.676
# 14      12.600
# 15      12.514
# 16      12.396
# 17      12.356
# 18      12.418
# 19      12.560
# 20      12.700
# 21      12.834
# 22      12.926
# 23      12.850
# 24      12.714
# 25      12.542
# 26      12.454
# 27      12.210
# 28      12.010
# 29      11.812
#          ...
# 2147    21.992
# 2148    21.984
# 2149    22.098
# 2150    22.188
# 2151    22.080
# 2152    21.990
# 2153    22.008
# 2154    22.068
# 2155    21.942
# 2156    21.878
# 2157    21.818
# 2158    21.728
# 2159    21.594
# 2160    21.730
# 2161    21.920
# 2162    22.196
# 2163    22.382
# 2164    22.276
# 2165    22.312
# 2166    22.168
# 2167    21.838
# 2168    21.496
# 2169    21.412
# 2170    21.456
# 2171    21.682
# 2172    21.916
# 2173    22.252
# ...

# %%
df.head()
# Out:
#    Unnamed: 0    ts_code  trade_date   open   high    low  close  pre_close  \
# 0           0  000001.SZ    20190402  13.28  13.48  13.23  13.36      13.18
# 1           1  000001.SZ    20190401  12.83  13.55  12.83  13.18      12.82
# 2           2  000001.SZ    20190329  12.26  12.82  12.21  12.82      12.22
# 3           3  000001.SZ    20190328  12.31  12.31  12.10  12.22      12.38
# 4           4  000001.SZ    20190327  12.24  12.47  12.18  12.38      12.10
#
#    change  pct_chg         vol       amount    MA_5  MA_10  MA_20  MA_100  \
# 0    0.18   1.3657  1100384.04  1466040.987     NaN    NaN    NaN     NaN
# 1    0.36   2.8081  1951401.19  2588268.668     NaN    NaN    NaN     NaN
# 2    0.60   4.9100  1669506.47  2108295.393     NaN    NaN    NaN     NaN
# 3   -0.16  -1.2924   732467.44   892530.627     NaN    NaN    NaN     NaN
# 4    0.28   2.3140   922826.80  1138302.657  12.792    NaN    NaN     NaN
#
#         EMA5      EMA10      EMA20     EMA100
# ...

# %%
df['MA_10'].plot()

# %%
df['MA_20'].plot()

# %%
df['MA_100'].plot()

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./data/000725.csv')

# %%
ma_list = [5, 10, 20, 100]
for ma in ma_list:
    df['MA' + str(ma)] = df['close'].rolling(5).mean()
for ma in ma_list:
    df['EMA' + str(ma)] = df['close'].ewm(span = 5).mean()

# %%
df
# Out:
#       Unnamed: 0    ts_code  trade_date  open  high   low  close  pre_close  \
# 0              0  000725.SZ    20190402  4.02  4.04  3.96   3.97       4.01
# 1              1  000725.SZ    20190401  3.91  4.04  3.91   4.01       3.90
# 2              2  000725.SZ    20190329  3.81  3.92  3.74   3.90       3.82
# 3              3  000725.SZ    20190328  3.78  3.93  3.75   3.82       3.80
# 4              4  000725.SZ    20190327  3.85  3.88  3.73   3.80       3.85
# 5              5  000725.SZ    20190326  4.03  4.06  3.82   3.85       4.05
# 6              6  000725.SZ    20190325  3.99  4.19  3.96   4.05       4.07
# 7              7  000725.SZ    20190322  4.08  4.12  3.98   4.07       3.93
# 8              8  000725.SZ    20190321  3.90  3.99  3.88   3.93       3.91
# 9              9  000725.SZ    20190320  3.95  3.95  3.84   3.91       3.95
# 10            10  000725.SZ    20190319  3.86  4.02  3.84   3.95       3.87
# ...

# %%
df.fillna(value = 0)
# Out:
#       Unnamed: 0    ts_code  trade_date  open  high   low  close  pre_close  \
# 0              0  000725.SZ    20190402  4.02  4.04  3.96   3.97       4.01
# 1              1  000725.SZ    20190401  3.91  4.04  3.91   4.01       3.90
# 2              2  000725.SZ    20190329  3.81  3.92  3.74   3.90       3.82
# 3              3  000725.SZ    20190328  3.78  3.93  3.75   3.82       3.80
# 4              4  000725.SZ    20190327  3.85  3.88  3.73   3.80       3.85
# 5              5  000725.SZ    20190326  4.03  4.06  3.82   3.85       4.05
# 6              6  000725.SZ    20190325  3.99  4.19  3.96   4.05       4.07
# 7              7  000725.SZ    20190322  4.08  4.12  3.98   4.07       3.93
# 8              8  000725.SZ    20190321  3.90  3.99  3.88   3.93       3.91
# 9              9  000725.SZ    20190320  3.95  3.95  3.84   3.91       3.95
# 10            10  000725.SZ    20190319  3.86  4.02  3.84   3.95       3.87
# ...

# %%
df.shape
# Out:
# (2231, 20)

# %%
a = df[0:100]

# %%
a
# Out:
#     Unnamed: 0    ts_code  trade_date  open  high   low  close  pre_close  \
# 0            0  000725.SZ    20190402  4.02  4.04  3.96   3.97       4.01
# 1            1  000725.SZ    20190401  3.91  4.04  3.91   4.01       3.90
# 2            2  000725.SZ    20190329  3.81  3.92  3.74   3.90       3.82
# 3            3  000725.SZ    20190328  3.78  3.93  3.75   3.82       3.80
# 4            4  000725.SZ    20190327  3.85  3.88  3.73   3.80       3.85
# 5            5  000725.SZ    20190326  4.03  4.06  3.82   3.85       4.05
# 6            6  000725.SZ    20190325  3.99  4.19  3.96   4.05       4.07
# 7            7  000725.SZ    20190322  4.08  4.12  3.98   4.07       3.93
# 8            8  000725.SZ    20190321  3.90  3.99  3.88   3.93       3.91
# 9            9  000725.SZ    20190320  3.95  3.95  3.84   3.91       3.95
# 10          10  000725.SZ    20190319  3.86  4.02  3.84   3.95       3.87
# 11          11  000725.SZ    20190318  3.82  3.87  3.74   3.87       3.82
# ...

# %%
a['close'].plot()

# %%
#死叉
#df[df['MA5'][t] >= df['MA10'][t] &  df['MA5'][t+1] < df['MA10'][t+1]]
#金叉
#df[df['MA5'][t] <= df['MA10'][t] &  df['MA5'][t+1] > df['MA10'][t+1]]

# %%
df = df.fillna(value = 0)

# %%
df['MA5'][6]
# Out:
# 3.8840000000000003

# %%
df
# Out:
#       Unnamed: 0    ts_code  trade_date  open  high   low  close  pre_close  \
# 0              0  000725.SZ    20190402  4.02  4.04  3.96   3.97       4.01
# 1              1  000725.SZ    20190401  3.91  4.04  3.91   4.01       3.90
# 2              2  000725.SZ    20190329  3.81  3.92  3.74   3.90       3.82
# 3              3  000725.SZ    20190328  3.78  3.93  3.75   3.82       3.80
# 4              4  000725.SZ    20190327  3.85  3.88  3.73   3.80       3.85
# 5              5  000725.SZ    20190326  4.03  4.06  3.82   3.85       4.05
# 6              6  000725.SZ    20190325  3.99  4.19  3.96   4.05       4.07
# 7              7  000725.SZ    20190322  4.08  4.12  3.98   4.07       3.93
# 8              8  000725.SZ    20190321  3.90  3.99  3.88   3.93       3.91
# 9              9  000725.SZ    20190320  3.95  3.95  3.84   3.91       3.95
# 10            10  000725.SZ    20190319  3.86  4.02  3.84   3.95       3.87
# ...

# %%
df.dropna()
golden_cross = df[(df['MA5'] >= df['MA10'] )&  (df['MA5'] < df['MA10'])]
death_cross = df[(df['MA5'] <= df['MA10'] )&  (df['MA5'] > df['MA10'])]

# %%
print(golden_cross)
print(death_cross)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, ts_code, trade_date, open, high, low, close, pre_close, change, pct_chg, vol, amount, MA5, MA10, MA20, MA100, EMA5, EMA10, EMA20, EMA100]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0, ts_code, trade_date, open, high, low, close, pre_close, change, pct_chg, vol, amount, MA5, MA10, MA20, MA100, EMA5, EMA10, EMA20, EMA100]
# Index: []

# %%
import matplotlib.pyplot as plt

# %%
plt.subplot(2, 2, 1)
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('000725')
plt.plot(df['close'][1:100], 'r')
plt.subplot(2, 2, 2)
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('000725')
plt.plot(df['close'][100:200], 'b')
plt.show()
plt.subplot(2, 2, 3)
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('000725')
plt.plot(df['close'][100:300], 'b')
plt.subplot(2, 2, 4)
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('000725')
plt.plot(df['close'][100:400], 'b')

# %%
df['close'].plot()

# %%
df['MA5'].plot()

# %%
df['MA10'].plot()

# %%
df['MA'] = df['close'].rolling(30).mean()

# %%
df['MA'].plot()

# %%
df['MA10'] = df['close'].rolling(10).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-69-24f9d813a022> in <module>
# ----> 1 df['MA10'] = df['close'].rolling(10).mean()
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     765         key = com._apply_if_callable(key, self)
#     766         try:
# --> 767             result = self.index.get_value(self, key)
#     768
#     769             if not is_scalar(result):
#
# ...

# %%
df['trade_date'](ascending = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-e66f6980fb95> in <module>
# ----> 1 df['trade_date'](ascending = False)
#
# TypeError: 'Series' object is not callable

# %%
df = df.sort_index(by=['trade_date'], ascending = True)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: by argument to sort_index is deprecated, please use .sort_values(by=...)
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#       Unnamed: 0    ts_code  trade_date   open   high    low  close  \
# 2176        2176  000001.SZ    20100104  24.52  24.58  23.68  23.71
# 2175        2175  000001.SZ    20100105  23.75  23.90  22.75  23.30
# 2174        2174  000001.SZ    20100106  23.25  23.25  22.72  22.90
# 2173        2173  000001.SZ    20100107  22.90  23.05  22.40  22.65
# 2172        2172  000001.SZ    20100108  22.50  22.75  22.35  22.60
# 2171        2171  000001.SZ    20100111  23.50  23.68  22.28  22.60
# 2170        2170  000001.SZ    20100112  22.57  22.65  21.80  22.45
# 2169        2169  000001.SZ    20100113  21.87  21.90  20.80  20.96
# 2168        2168  000001.SZ    20100114  21.00  21.16  20.60  20.97
# 2167        2167  000001.SZ    20100115  21.02  21.65  20.65  21.43
# 2166        2166  000001.SZ    20100118  21.43  21.76  21.21  21.47
# 2165        2165  000001.SZ    20100119  21.58  22.34  21.56  22.23
# 2164        2164  000001.SZ    20100120  22.22  22.60  21.30  21.38
# ...

# %%
df
# Out:
#       Unnamed: 0    ts_code  trade_date   open   high    low  close  \
# 2176        2176  000001.SZ    20100104  24.52  24.58  23.68  23.71
# 2175        2175  000001.SZ    20100105  23.75  23.90  22.75  23.30
# 2174        2174  000001.SZ    20100106  23.25  23.25  22.72  22.90
# 2173        2173  000001.SZ    20100107  22.90  23.05  22.40  22.65
# 2172        2172  000001.SZ    20100108  22.50  22.75  22.35  22.60
# 2171        2171  000001.SZ    20100111  23.50  23.68  22.28  22.60
# 2170        2170  000001.SZ    20100112  22.57  22.65  21.80  22.45
# 2169        2169  000001.SZ    20100113  21.87  21.90  20.80  20.96
# 2168        2168  000001.SZ    20100114  21.00  21.16  20.60  20.97
# 2167        2167  000001.SZ    20100115  21.02  21.65  20.65  21.43
# 2166        2166  000001.SZ    20100118  21.43  21.76  21.21  21.47
# 2165        2165  000001.SZ    20100119  21.58  22.34  21.56  22.23
# 2164        2164  000001.SZ    20100120  22.22  22.60  21.30  21.38
# ...

# %%
20190402 in df['trade_date']
# Out:
# False

# %%
for t in df['trade_date']:
    print(t)
# Out:
# 20100104
# 20100105
# 20100106
# 20100107
# 20100108
# 20100111
# 20100112
# 20100113
# 20100114
# 20100115
# 20100118
# 20100119
# 20100120
# 20100121
# 20100122
# 20100125
# 20100126
# 20100127
# 20100128
# 20100129
# 20100201
# 20100202
# 20100203
# 20100204
# 20100205
# 20100208
# 20100209
# 20100210
# 20100211
# 20100212
# 20100222
# 20100223
# 20100224
# 20100225
# 20100226
# 20100302
# 20100303
# 20100304
# 20100305
# 20100308
# 20100309
# 20100310
# 20100311
# 20100312
# 20100315
# 20100316
# 20100317
# 20100318
# 20100319
# 20100322
# 20100323
# 20100324
# 20100325
# 20100326
# 20100329
# 20100330
# 20100331
# 20100401
# 20100402
# 20100406
# 20100407
# 20100408
# 20100409
# 20100412
# 20100413
# 20100414
# 20100415
# 20100416
# 20100419
# 20100420
# 20100421
# 20100422
# 20100423
# 20100426
# 20100427
# 20100428
# 20100429
# 20100430
# 20100504
# 20100505
# 20100506
# 20100507
# 20100510
# 20100511
# 20100512
# 20100513
# 20100514
# 20100517
# 20100518
# 20100519
# ...

# %%
a = df[0:1]['trade_date']

# %%
a
# Out:
# 2176    20100104
# Name: trade_date, dtype: int64

# %%
int(a)
# Out:
# 20100104

# %%
x, y = df.shape

# %%
x
# Out:
# 2177

# %%
df.loc[0]['close']
# Out:
# 13.36

# %%
df['MA'] = df['close'].rolling(5).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-7563098db217> in <module>
# ----> 1 df['MA'] = df['close'].rolling(5).mean()
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     765         key = com._apply_if_callable(key, self)
#     766         try:
# --> 767             result = self.index.get_value(self, key)
#     768
#     769             if not is_scalar(result):
#
# ...

# %%
df
# Out:
# 2176       NaN
# 2175       NaN
# 2174       NaN
# 2173       NaN
# 2172    23.032
# 2171    22.810
# 2170    22.640
# 2169    22.252
# 2168    21.916
# 2167    21.682
# 2166    21.456
# 2165    21.412
# 2164    21.496
# 2163    21.838
# 2162    22.168
# 2161    22.312
# 2160    22.276
# 2159    22.382
# 2158    22.196
# 2157    21.920
# 2156    21.730
# 2155    21.594
# 2154    21.728
# 2153    21.818
# 2152    21.878
# 2151    21.942
# 2150    22.068
# 2149    22.008
# 2148    21.990
# 2147    22.080
#          ...
# 29      11.248
# 28      11.270
# 27      11.388
# 26      11.626
# 25      11.812
# 24      12.010
# 23      12.210
# 22      12.454
# 21      12.542
# 20      12.714
# 19      12.850
# 18      12.926
# 17      12.834
# 16      12.700
# 15      12.560
# 14      12.418
# 13      12.356
# 12      12.396
# 11      12.514
# 10      12.600
# 9       12.676
# 8       12.728
# 7       12.746
# 6       12.586
# 5       12.448
# 4       12.374
# 3       12.280
# ...

# %%
df.dropna()
# Out:
# 2172    23.032
# 2171    22.810
# 2170    22.640
# 2169    22.252
# 2168    21.916
# 2167    21.682
# 2166    21.456
# 2165    21.412
# 2164    21.496
# 2163    21.838
# 2162    22.168
# 2161    22.312
# 2160    22.276
# 2159    22.382
# 2158    22.196
# 2157    21.920
# 2156    21.730
# 2155    21.594
# 2154    21.728
# 2153    21.818
# 2152    21.878
# 2151    21.942
# 2150    22.068
# 2149    22.008
# 2148    21.990
# 2147    22.080
# 2146    22.188
# 2145    22.098
# 2144    21.984
# 2143    21.992
#          ...
# 29      11.248
# 28      11.270
# 27      11.388
# 26      11.626
# 25      11.812
# 24      12.010
# 23      12.210
# 22      12.454
# 21      12.542
# 20      12.714
# 19      12.850
# 18      12.926
# 17      12.834
# 16      12.700
# 15      12.560
# 14      12.418
# 13      12.356
# 12      12.396
# 11      12.514
# 10      12.600
# 9       12.676
# 8       12.728
# 7       12.746
# 6       12.586
# 5       12.448
# 4       12.374
# 3       12.280
# ...

# %%
df
# Out:
# 2176       NaN
# 2175       NaN
# 2174       NaN
# 2173       NaN
# 2172    23.032
# 2171    22.810
# 2170    22.640
# 2169    22.252
# 2168    21.916
# 2167    21.682
# 2166    21.456
# 2165    21.412
# 2164    21.496
# 2163    21.838
# 2162    22.168
# 2161    22.312
# 2160    22.276
# 2159    22.382
# 2158    22.196
# 2157    21.920
# 2156    21.730
# 2155    21.594
# 2154    21.728
# 2153    21.818
# 2152    21.878
# 2151    21.942
# 2150    22.068
# 2149    22.008
# 2148    21.990
# 2147    22.080
#          ...
# 29      11.248
# 28      11.270
# 27      11.388
# 26      11.626
# 25      11.812
# 24      12.010
# 23      12.210
# 22      12.454
# 21      12.542
# 20      12.714
# 19      12.850
# 18      12.926
# 17      12.834
# 16      12.700
# 15      12.560
# 14      12.418
# 13      12.356
# 12      12.396
# 11      12.514
# 10      12.600
# 9       12.676
# 8       12.728
# 7       12.746
# 6       12.586
# 5       12.448
# 4       12.374
# 3       12.280
# ...

# %%
import pandas
